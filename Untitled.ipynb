# %%
import pandas as pd
import numpy as np
import xlrd
import os 

path = './'

read_csv = os.path.join(path, "ENB2012_data.xlsx")
df = pd.read_excel(read_csv)

df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# 5    0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.46  25.38
# 6    0.90  563.5  318.5  122.50  7.0   4  0.0   0  20.71  25.16
# 7    0.90  563.5  318.5  122.50  7.0   5  0.0   0  19.68  29.60
# 8    0.86  588.0  294.0  147.00  7.0   2  0.0   0  19.50  27.30
# 9    0.86  588.0  294.0  147.00  7.0   3  0.0   0  19.95  21.97
# 10   0.86  588.0  294.0  147.00  7.0   4  0.0   0  19.34  23.49
# 11   0.86  588.0  294.0  147.00  7.0   5  0.0   0  18.31  27.87
# 12   0.82  612.5  318.5  147.00  7.0   2  0.0   0  17.05  23.77
# 13   0.82  612.5  318.5  147.00  7.0   3  0.0   0  17.41  21.46
# ...

# %%
df.columns = ['Rel Compacteness', 'Surface Area', 'Wall Area', 'Roof Area', 'Overall Height', 'Orientation', 'Glazing Area', 'Glazing Area Distribution', 'Heating Load', 'Cooling Load']
df
# Out:
#      Rel Compacteness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                0.98         514.5      294.0     110.25             7.0
# 1                0.98         514.5      294.0     110.25             7.0
# 2                0.98         514.5      294.0     110.25             7.0
# 3                0.98         514.5      294.0     110.25             7.0
# 4                0.90         563.5      318.5     122.50             7.0
# 5                0.90         563.5      318.5     122.50             7.0
# 6                0.90         563.5      318.5     122.50             7.0
# 7                0.90         563.5      318.5     122.50             7.0
# 8                0.86         588.0      294.0     147.00             7.0
# 9                0.86         588.0      294.0     147.00             7.0
# 10               0.86         588.0      294.0     147.00             7.0
# 11               0.86         588.0      294.0     147.00             7.0
# ...

# %%
from scipy.stats import zscore

x_columns = df.columns
for col in x_columns:
    df[col] = zscore(df[col])
    
x = df[x_columns].values
    
df.head()
# Out:
#    Rel Compacteness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0          2.041777     -1.785875  -0.561951  -1.470077             1.0
# 1          2.041777     -1.785875  -0.561951  -1.470077             1.0
# 2          2.041777     -1.785875  -0.561951  -1.470077             1.0
# 3          2.041777     -1.785875  -0.561951  -1.470077             1.0
# 4          1.284979     -1.229239   0.000000  -1.198678             1.0
#
#    Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 0    -1.341641     -1.760447                  -1.814575     -0.670115
# 1    -0.447214     -1.760447                  -1.814575     -0.670115
# 2     0.447214     -1.760447                  -1.814575     -0.670115
# 3     1.341641     -1.760447                  -1.814575     -0.670115
# 4    -1.341641     -1.760447                  -1.814575     -0.145503
#
#    Cooling Load
# 0     -0.342666
# 1     -0.342666
# 2     -0.342666
# 3     -0.342666
# 4      0.388366

# %%
#remove Orientation, Surface Area and Roof Area from data due to negative and low correlation
X = df[['Rel Compacteness', 'Wall Area', 'Overall Height', 'Glazing Area', 'Glazing Area Distribution']].values
y1 = df[['Heating Load']].values
y2 = df[['Cooling Load']].values

# %%
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# Cross-Validate
kf = KFold(5, shuffle=True, random_state=42) 
    
oos_y = []
oos_pred = []

fold = 0

for train, test in kf.split(x):
    fold+=1
    print(f"Fold #{fold}")
        
    x1_train = X[train]
    y1_train = y1[train]
    x1_test = X[test]
    y1_test = y1[test]
    
    
    x2_train = X[train]
    y2_train = y2[train]
    x2_test = X[test]
    y2_test = y2[test]
    
    
    model = Sequential()
    model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    model.fit(x1_train,y1_train,validation_data=(x1_test,y1_test),verbose=0,epochs=500)
    model.fit(x2_train,y2_train,validation_data=(x2_test,y2_test),verbose=0,epochs=500)
    
    
    
    #X1_train, X1_test, y1_train, y1_test = train_test_split(X, y1, test_size = 0.25, random_state = 0)
    #X2_train, X2_test, y2_train, y2_test = train_test_split(X, y2, test_size = 0.25, random_state = 0)
    
    
    
    pred1 = model.predict(x1_test)
    pred2 = model.predict(x2_test)
    
    oos_y.append(y1_test)
    oos_y.append(y2_test)
    
    oos_pred.append(pred1)    
    oos_pred.append(pred2) 

    # Measure this fold's RMSE
    score = np.sqrt(metrics.mean_squared_error(pred1,y1_test))
    print(f"Fold score for heating (RMSE): {score}")
    
    score = np.sqrt(metrics.mean_squared_error(pred2,y2_test))
    print(f"Fold score for cooling (RMSE): {score}")
    

# Build the oos prediction list and calculate the error.
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
score = np.sqrt(metrics.mean_squared_error(oos_pred,oos_y))
print(f"Final, out of sample score (RMSE): {score}")    
    
# Write the cross-validated prediction
oos_y = pd.DataFrame(oos_y)
oos_pred = pd.DataFrame(oos_pred)
oosDF = pd.concat( [df, oos_y, oos_pred],axis=1 )
print(oosDF)
#oosDF.to_csv(filename_write,index=False)
# Out:
# Fold #1
# Fold score for heating (RMSE): 0.11839176668898772
# Fold score for cooling (RMSE): 0.20184804933489062
# Fold #2
# Fold score for heating (RMSE): 0.13097027961504393
# Fold score for cooling (RMSE): 0.20945440289752654
# Fold #3
# Fold score for heating (RMSE): 0.12052355133231107
# Fold score for cooling (RMSE): 0.1783578783002292
# Fold #4
# Fold score for heating (RMSE): 0.10087788561043734
# Fold score for cooling (RMSE): 0.19948403407854076
# Fold #5
# Fold score for heating (RMSE): 0.12819946264037355
# Fold score for cooling (RMSE): 0.17012632142343032
# Final, out of sample score (RMSE): 0.16047401558205934
#       Rel Compacteness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0             2.041777     -1.785875  -0.561951  -1.470077             1.0
# 1             2.041777     -1.785875  -0.561951  -1.470077             1.0
# 2             2.041777     -1.785875  -0.561951  -1.470077             1.0
# ...
